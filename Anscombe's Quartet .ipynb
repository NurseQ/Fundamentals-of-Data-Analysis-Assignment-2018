# %% [markdown]
# # Anscombe's quartet dataset
#
# James Quintin
#
# This notebook is an investigation of Anscombe's quartet dataset. This notebook starts with a background of the dataset including a brief review of how such a dataset can be be created. The dataset is then loaded in the notebook and several ways of selecting a dataframe out of the file is demonstrated. Graphical representations and statistical analysis are then presented to further analyse the dataset. A discussion section then follows to explain the interesting aspects of the dataset.
#
# #### Background of the dataset
#
# This dataset was created by statistician Francis Anscombe in 1973.  It is a set of four datasets that have similar or identical statistical properties [1] but vary dramatically when plotted in a graph. Anscombe created the datasets to highlight the importance of visualising graphs and to debunk flawed conventions around the use of graphs in mathematics and statistics at that time. Visualization of data provides "the context necessary to make better choices and to be more careful when fitting models" [2].
#
# Matejka and Fitzmaurice [3] reports that Anscombe did not show or suggest how the dataset was created or how it can be reproduced. There are several attempts at creating an algorithm to produce datasets with similar statistics and have unidentical plots/graphs. Matejka and Fitzmaurice [3] reported that Chatterjee and Firat proposed a genetic algorithm technique that created 1,000 random datasets with identical statistics then combined and mutated with an objective function to maximize dissimilarity of the plots. Matejka and Fitzmaurice [3] also developed a method to use an existing dataset and modify it, and by repeating the process, create datasets with different graphical appearance and identical statistical properties. Using their algorithm, they are also able demonstrate scatter plots that resemble different shapes that have similar descriptive statistics, standard deviation and correlation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# import pandas and load quartet csv file from url

import pandas as pd
df = pd.read_csv("https://gist.githubusercontent.com/ericbusboom/b2ac1d366c005cd2ed8c/raw/c92c66e43d144fa9c29dbd602d5af6988e8db533/anscombes.csv")
 
df
# Out:
#     id dataset     x      y
# 0    0       I  10.0   8.04
# 1    1       I   8.0   6.95
# 2    2       I  13.0   7.58
# 3    3       I   9.0   8.81
# 4    4       I  11.0   8.33
# 5    5       I  14.0   9.96
# 6    6       I   6.0   7.24
# 7    7       I   4.0   4.26
# 8    8       I  12.0  10.84
# 9    9       I   7.0   4.82
# 10  10       I   5.0   5.68
# 11  11      II  10.0   9.14
# 12  12      II   8.0   8.14
# 13  13      II  13.0   8.74
# 14  14      II   9.0   8.77
# 15  15      II  11.0   9.26
# 16  16      II  14.0   8.10
# 17  17      II   6.0   6.13
# 18  18      II   4.0   3.10
# 19  19      II  12.0   9.13
# 20  20      II   7.0   7.26
# 21  21      II   5.0   4.74
# 22  22     III  10.0   7.46
# 23  23     III   8.0   6.77
# 24  24     III  13.0  12.74
# 25  25     III   9.0   7.11
# 26  26     III  11.0   7.81
# 27  27     III  14.0   8.84
# 28  28     III   6.0   6.08
# 29  29     III   4.0   5.39
# 30  30     III  12.0   8.15
# 31  31     III   7.0   6.42
# ...

# %% [markdown]
# #### Use loc and iloc to select columns and rows for investigation and manipulation.

# %%
# To get row labelled 11 to 21 and all corresponding values in column 'x' and 'y'.

df.loc[11:21,['x','y']]
# Out:
#        x     y
# 11  10.0  9.14
# 12   8.0  8.14
# 13  13.0  8.74
# 14   9.0  8.77
# 15  11.0  9.26
# 16  14.0  8.10
# 17   6.0  6.13
# 18   4.0  3.10
# 19  12.0  9.13
# 20   7.0  7.26
# 21   5.0  4.74

# %%
# To get values in index 2 column from row index 33 to 43

df.iloc[33:44, 2]
# Out:
# 33     8.0
# 34     8.0
# 35     8.0
# 36     8.0
# 37     8.0
# 38     8.0
# 39     8.0
# 40    19.0
# 41     8.0
# 42     8.0
# 43     8.0
# Name: x, dtype: float64

# %%
# Use pandas to compare the values in the 'dataset' column to a specific value, in this case 'I', and output Boolean value. 

df.loc[:, 'dataset']=='I'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# Name: dataset, dtype: bool

# %%
# Select a new dataframe excluding the column 'id'. 

df1 = df.loc[:, ['dataset', 'x', 'y']]
df1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# #### Use the seaborn package to visualize the data

# %%
# Load the seaborn package.

import seaborn as sns

# Plot Anscombes Quartet data set with a pair plot.

sns.pairplot(df1, hue ='dataset')

# %%
# Selecting all values in 'dataset' column with corresponding 'I' value.

a = df1.loc[df1.loc[:,'dataset']=='I']

# %%
# the first dataset
a
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
# Takes values from spliced dataframe above and assigns them into x and y axis then plot them with seaborn.

ax = a.loc[:, 'x']
ay = a.loc[:, 'y']

sns.regplot(ax,ay)

# %%
# Descriptive statistics of values in all columns in a.

a.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
# Selecting all values in 'dataset' column with corresponding 'II' value, the second dataset.

b = df1.loc[df1.loc[:,'dataset']=='II']
b
# Out:
#    dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74

# %%
# Takes values from spliced dataframe above and assigns them into x and y axis then plot them with seaborn.

bx = b.loc[:, 'x']
by = b.loc[:, 'y']
sns.regplot(bx,by)

# %%
b.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
# Selecting all values in 'dataset' column with corresponding 'III' value, the third dataset.

c = df1.loc[df1.loc[:,'dataset']=='III']
c
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %%
# Takes values from spliced dataframe above and assigns them into x and y axis then plot them with seaborn.

cx = c.loc[:, 'x']
cy = c.loc[:, 'y']
sns.regplot(cx,cy)

# %%
c.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
# Selecting all values in 'dataset' column with corresponding 'IV' value, the fourth dataset.

d = df1.loc[df1.loc[:,'dataset']=='IV']
d
# Out:
#    dataset     x      y
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
# Takes values from spliced dataframe above and assigns them into x and y axis then plot them with seaborn.

dx = d.loc[:, 'x']
dy = d.loc[:, 'y']
sns.regplot(dx,dy)

# %%
d.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# #### Discussion
#
# Anscombe's dataset demonstrates the importance of visualizing the data graphically. The summary of the statistical analyses of the datasets can be misleading on its own. The mean of the x and y columns are basically the same for each of the datasets, give or take values from the fourth decimal place in column y. This is also the case for the variance for both, so the standard deviation is also identical.
#
# The regplot function of seaborn is used to visualize the data including the linear relationship, which is determined through regression. The best fit line drawn over the plots are also similar as the correlation coefficient of both x and y are similar.
#
# The selected dataframe above labeled as 'a' is the first dataset in Anscombe's quartet. The scatter plot reveals a simple linear relationship with some variance. It appears to be a good fit for linear regression.
#
# The second dataframe labeled as 'b' shows a scatter plot that follows a curve. Linear regression may not be the appropriate determinant of correlation in this instance.
#
# The third dataframe labeled as 'c' shows a scatter plot that seem to follow a linear distribution. There is one outlier though that changes the correlation coefficient lower from a 1 to 0.816 [4]. This example of how an outlier can affect data is made more obvious with visualization.
#
# The fourth dataframe labeled as 'd' shows another scatter plot with an outlier. The regression line is obviously thrown off by the effect of the one outlier. This demostrates clearly how the outlier, which has no discernible relationship with the other data points can influence the appearance of a high correlation.
#
# Anscombe's dataset clearly shows the need to visualize data and to use it to supplement any statistical analysis.
#
# #### References
#
# [1] Idris, I. Python Data Analysis Cookbook.
#     https://www.oreilly.com/library/view/python-data-analysis/9781785282287/ch02s02.html
#
# [2] Anon. https://rstudio-pubs-static.s3.amazonaws.com/52381_36ec82827e4b476fb968d9143aec7c4f.html
#
# [3] Matejka, J., and Fitzmaurice, G. (2017). Same Stats, Different Graphs: Generating Datasets with Varied Appearance and Identical Statistics through simulated Annealing. https://www.autodeskresearch.com
#
# [4] Wikipedia. https://en.wikipedia.org/wiki/Anscombe%27s_quartet
